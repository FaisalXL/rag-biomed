# %% [markdown]
# # Adaptive RAG demo (short shootout)
#
# **Python twin:** `examples/adaptive_rag_demo.py` — same flow, no Jupyter.
#
# Requires prior runs of `scripts/02`–`04`, and ideally `scripts/05` (or let the demo train XGBoost once). Uses fewer PubMedQA questions than the full `scripts/06` run.

# %%
from pathlib import Path
import os, sys

ROOT = Path.cwd().resolve()
if not (ROOT / "src").is_dir():
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / "src"))
os.chdir(ROOT)

# %%
from huggingface_hub import login
if os.environ.get("HF_TOKEN"):
    login(token=os.environ["HF_TOKEN"])

# %%
from adaptive_rag.demo_adaptive import run_adaptive_shootout_demo

summary, df = run_adaptive_shootout_demo(n_samples=25, train_xgb_if_missing=True)
df
