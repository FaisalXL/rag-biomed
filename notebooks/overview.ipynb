# %% [markdown]
# # Overview
#
# This notebook is the **Jupyter** counterpart of **`examples/overview_main.py`**. It does not load large models; it orients you to the repo.
#
# For the same text in a terminal:
#
# ```bash
# python examples/overview_main.py
# ```

# %%
import subprocess
import sys
from pathlib import Path

ROOT = Path.cwd().resolve()
if not (ROOT / "src").is_dir():
    ROOT = ROOT.parent
subprocess.run([sys.executable, str(ROOT / "examples/overview_main.py")], check=True)
